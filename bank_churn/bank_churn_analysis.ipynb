# %%
import pandas as pd

# %% [markdown]
# Want to predict if bank customers will churn, i.e. leave the bank, or not.

# %% [markdown]
# ### EDA on bank churn dataset

# %%
# importing the bank churn dataset
df = pd.read_csv('Bank Customer Churn Prediction.csv')

# %%
# getting info on the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# OK no null data, thats good. Lets look at the values.

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %% [markdown]
# customer_id irrelevant, can drop. gender can drop too, since we don't want to be changing how we are treating people of various genders and use it in our predictions. Not sure what products_number and active_member mean? tenure seems like it would be impacted by age, e.g. someone who is 20 yrs old probably wont have a high tenure. Do we want age to be used in our predictions? Probably not. I guess it depends on the interests of the bank; if we find out young people keep leaving, maybe we can find out why and tailor strategy to keep them?

# %%
df = df.drop(labels=['customer_id','gender'],axis=1)

# %%
# checking details of the numerical columns to see what we can learn about tenure-age relationship.
# do we have lots of young people, etc.
df.describe()
# Out:
#        credit_score           age        tenure        balance  \
# count  10000.000000  10000.000000  10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288
# std       96.653299     10.487806      2.892174   62397.405202
# min      350.000000     18.000000      0.000000       0.000000
# 25%      584.000000     32.000000      3.000000       0.000000
# 50%      652.000000     37.000000      5.000000   97198.540000
# 75%      718.000000     44.000000      7.000000  127644.240000
# max      850.000000     92.000000     10.000000  250898.090000
#
#        products_number  credit_card  active_member  estimated_salary  \
# count     10000.000000  10000.00000   10000.000000      10000.000000
# mean          1.530200      0.70550       0.515100     100090.239881
# std           0.581654      0.45584       0.499797      57510.492818
# min           1.000000      0.00000       0.000000         11.580000
# 25%           1.000000      0.00000       0.000000      51002.110000
# 50%           1.000000      1.00000       1.000000     100193.915000
# 75%           2.000000      1.00000       1.000000     149388.247500
# max           4.000000      1.00000       1.000000     199992.480000
#
#               churn
# count  10000.000000
# mean       0.203700
# std        0.402769
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# Max of tenure is only 10!? Ok thats really low considering 75% of people are over 32 years old. People really switch banks that often? Mean of churn is 0.2, meaning we have a skewed data set since the variable is binary.

# %%
# lets check if tenure changes a lot for younger people
df_young = df[df['age']<32]
df_young.describe()
# Out:
#        credit_score          age       tenure        balance  products_number  \
# count   2372.000000  2372.000000  2372.000000    2372.000000      2372.000000
# mean     651.560708    27.351602     5.032040   73591.305232         1.554384
# std       96.312125     3.171252     2.848306   62959.481157         0.534742
# min      363.000000    18.000000     0.000000       0.000000         1.000000
# 25%      582.000000    25.000000     3.000000       0.000000         1.000000
# 50%      653.000000    28.000000     5.000000   93597.185000         2.000000
# 75%      717.000000    30.000000     7.000000  126701.625000         2.000000
# max      850.000000    31.000000    10.000000  214346.960000         4.000000
#
#        credit_card  active_member  estimated_salary        churn
# count  2372.000000    2372.000000       2372.000000  2372.000000
# mean      0.711636       0.513069     100765.968347     0.076307
# std       0.453097       0.499935      58875.806811     0.265545
# min       0.000000       0.000000         90.070000     0.000000
# 25%       0.000000       0.000000      48573.812500     0.000000
# 50%       1.000000       1.000000     103309.370000     0.000000
# 75%       1.000000       1.000000     151968.192500     0.000000
# max       1.000000       1.000000     199953.330000     1.000000

# %% [markdown]
# Oh interesting, the churn rate is much lower for young people. Also the tenure is basically the same.

# %% [markdown]
# Thinking about modeling now, probably wanna start with Naive Bayes since we have binary target variable. Lets check correlation and encode the categorical variables

# %%
df_corr = df.corr(numeric_only=True)
df_corr
# Out:
#                   credit_score       age    tenure   balance  products_number  \
# credit_score          1.000000 -0.003965  0.000842  0.006268         0.012238
# age                  -0.003965  1.000000 -0.009997  0.028308        -0.030680
# tenure                0.000842 -0.009997  1.000000 -0.012254         0.013444
# balance               0.006268  0.028308 -0.012254  1.000000        -0.304180
# products_number       0.012238 -0.030680  0.013444 -0.304180         1.000000
# credit_card          -0.005458 -0.011721  0.022583 -0.014858         0.003183
# active_member         0.025651  0.085472 -0.028362 -0.010084         0.009612
# estimated_salary     -0.001384 -0.007201  0.007784  0.012797         0.014204
# churn                -0.027094  0.285323 -0.014001  0.118533        -0.047820
#
#                   credit_card  active_member  estimated_salary     churn
# credit_score        -0.005458       0.025651         -0.001384 -0.027094
# age                 -0.011721       0.085472         -0.007201  0.285323
# tenure               0.022583      -0.028362          0.007784 -0.014001
# balance             -0.014858      -0.010084          0.012797  0.118533
# products_number      0.003183       0.009612          0.014204 -0.047820
# credit_card          1.000000      -0.011866         -0.009933 -0.007138
# active_member       -0.011866       1.000000         -0.011421 -0.156128
# estimated_salary    -0.009933      -0.011421          1.000000  0.012097
# churn               -0.007138      -0.156128          0.012097  1.000000

# %%
# checking correlation since we want to use Naive Bayes
df_corr = df_corr[(df_corr>0.25)|(df_corr<-0.25)]
df_corr
# Out:
#                   credit_score       age  tenure  balance  products_number  \
# credit_score               1.0       NaN     NaN      NaN              NaN
# age                        NaN  1.000000     NaN      NaN              NaN
# tenure                     NaN       NaN     1.0      NaN              NaN
# balance                    NaN       NaN     NaN  1.00000         -0.30418
# products_number            NaN       NaN     NaN -0.30418          1.00000
# credit_card                NaN       NaN     NaN      NaN              NaN
# active_member              NaN       NaN     NaN      NaN              NaN
# estimated_salary           NaN       NaN     NaN      NaN              NaN
# churn                      NaN  0.285323     NaN      NaN              NaN
#
#                   credit_card  active_member  estimated_salary     churn
# credit_score              NaN            NaN               NaN       NaN
# age                       NaN            NaN               NaN  0.285323
# tenure                    NaN            NaN               NaN       NaN
# balance                   NaN            NaN               NaN       NaN
# products_number           NaN            NaN               NaN       NaN
# credit_card               1.0            NaN               NaN       NaN
# active_member             NaN            1.0               NaN       NaN
# estimated_salary          NaN            NaN               1.0       NaN
# churn                     NaN            NaN               NaN  1.000000

# %% [markdown]
# ### Feature engineering

# %%
# checking for any shenanigans or non-conventional naming
df.value_counts('country')
# Out:
# country
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
# dummy encoding to convert categorical variables to binary
df = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# ### Modeling
